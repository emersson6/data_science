# %% [markdown]
# # Base de datos de ventas de un E-commerce de venta de vinos

# %%
# !pip install missingno
import missingno as msno
# %matplotlib inline

# %% [markdown]
# Esta base es el registro de todas las ventas por productos y cliente, se busca identificar patrones de compra, estacionalidades,
# Con el fin de segmentar los mejores cliente y tener los stocks para las demandas futuras.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/emersson6/data_science/main/DataSet3.csv'
df = pd.read_csv(url, index_col=0, sep=';')
df.head(5)
# Out:
#             Fecha  reference  Id_Cliente                Cliente  \
# Orden
# 14181  09-06-2020  QHCQNPRWD        4878   MARIA ANTONIETA PINO
# 14661  12-07-2020  ETUBXAFZD        4878   MARIA ANTONIETA PINO
# 16522  23-10-2020  BRFJVAQNA        4878   MARIA ANTONIETA PINO
# 17596  18-02-2021  LBLLKPNNK        4878   MARIA ANTONIETA PINO
# 19939  30-06-2021  UORDMDNIF        4878   MARIA ANTONIETA PINO
#
#       product_reference                            product_name  \
# Orden
# 14181           1142475        Molu Pinot Noir Bot ScrCap 6x750
# 14661           1142475        Molu Pinot Noir Bot ScrCap 6x750
# 16522           1142146  Reserva Carmenere Bot 12x750 Oct-Rosa
# 17596           1142083             Reserva Carmenere Bot 6x750
# 19939           1142082            Reserva Carmenere Bot 12x750
#
#        product_quantity  total_price_tax_incl  Total Pagado  \
# Orden
# 14181                 1                 20940         20940
# ...

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Base de datos de inspecciones de tuberias

# %% [markdown]
# La base de datos seleccionada corresponde a resultados obtenidos de dos inspecciones realizadas en dos años diferentes sobre una
# tuberia de transporte de gas. El objetivo del analisis propuesto consiste en evaluar el crecimiento de los defectos a lo largo del
# tiempo. Adicionalmente mediante un enfoque utilizando machine learning se podria evaluar la existencia de patrones en los valores
# relevados.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/emersson6/data_science/main/Datos_inspecciones.csv')
df.head(5)
# Out:
#    ID ILI 2021      WELD_REF       od  distancia sold  Profundidad  LARGO  \
# 0         96.0  1.000000e+09  259.025           8.336         20.0   30.0
# 1        137.0  1.000000e+09  351.886           3.598         28.0   10.0
# 2        178.0  1.000001e+09  465.540           0.489         25.0   14.0
# 3        181.0  1.000001e+09  465.977           0.926         24.0   88.0
# 4        187.0  1.000001e+09  466.413           1.362         20.0   28.0
#
#    ANCHO ubicacion Posicion clasificacion  ...  LARG    ANCH   ub  PosHor  \
# 0   15.0       INT    05:55          AXGR  ...   46.0   19.0  INT   06:03
# 1   15.0       INT    07:52          PITT  ...   19.0   19.0  INT   08:00
# 2   15.0       INT    05:46          PITT  ...   99.0   47.0  INT   05:51
# 3   39.0       INT    06:23          GENE  ...  365.0  220.0  INT   06:40
# 4  116.0       INT    05:57          CIGR  ...   36.0   26.0  INT   06:02
#
#    IDMach  Espesor  cantdepos Diferencia% Diferencia mm      Vcor
# ...

# %% [markdown]
# # Base de datos los partidos y resultados de los mundiales

# %% [markdown]
# Esta base de datos contiene los datos de los mundiales la fecha y hora del los partidos como tambien los resultados, se tiene
# un potencial de analisis muy interesante.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/emersson6/data_science/main/WorldCupMatches.csv'
df = pd.read_csv(url, index_col=0, sep=',')
df.head(5)
# Out:
#                     Datetime    Stage         Stadium         City  \
# Year
# 1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#        Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# Year
# 1930.0         France              4.0              1.0         Mexico
# 1930.0            USA              3.0              0.0        Belgium
# 1930.0     Yugoslavia              2.0              1.0         Brazil
# 1930.0        Romania              3.0              1.0           Peru
# 1930.0      Argentina              1.0              0.0         France
#
#        Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# Year
# ...
